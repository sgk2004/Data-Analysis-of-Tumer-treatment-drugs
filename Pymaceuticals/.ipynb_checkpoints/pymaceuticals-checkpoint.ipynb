# %%
# # Dependencies and Setup
#%matplotlib inline

#for an interactive plot
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %%
#Read the csv file - clinicaltrial_data.csv
file_path1= os.path.join('data','clinicaltrial_data.csv')
clinical_trial_df = pd.read_csv(file_path1)

# %%
#Read the csv file - mouse_drug_data.csv
file_path2= os.path.join('data','mouse_drug_data.csv')
mouse_drug_df = pd.read_csv(file_path2)

# %%
# Combine the data into a single dataset
merged_df = pd.merge(clinical_trial_df, mouse_drug_df, on=('Mouse ID'))
#merged_df.info()
# Display the data table for preview
#merged_df.head()

# %% [markdown]
# ## Tumor Response to Treatment

# %% [markdown]
# Find the Mean  of Tumor Volume(mm3) Data, Grouped by Drug and Timepoint

# %%
# Mean of Tumor Volume(mm3) Data, Grouped by Drug and Timepoint
mean_tv_df = pd.DataFrame(merged_df.groupby(['Drug', 'Timepoint']) ["Tumor Volume (mm3)"].mean())
#Reindexing DF
mean_tv_df=mean_tv_df.reset_index()
#preview
#mean_tv_df

# %%
# Minor Data Munging to Re-Format the Data Frames
# Preview that Reformatting worked

mean_df_pivot=mean_tv_df.pivot(index='Timepoint',columns='Drug', values='Tumor Volume (mm3)')

#preview
mean_df_pivot
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %% [markdown]
# Analyze the data to show how four treatments compare.

# %% [markdown]
# Mean of Tumor Volume (Capomulin, Infubinol, Ketapril, and Placebo)

# %%
#Capomulin:Round the mean to two decimal point and make a list of mean of Tumor Volume 
cap_tv_list=mean_df_pivot['Capomulin'].to_list()
cap_tv_list=[round(item, 2) for item in cap_tv_list]

# %%
#Ketapril:Round the mean to two decimal point and make a list of mean of Tumor Volume 
ket_tv_list=mean_df_pivot['Ketapril'].to_list()
ket_tv_list=[round(item, 2) for item in ket_tv_list]

# %%
# Infubinol :Round the mean to two decimal point and make a list of mean of Tumor Volume 
inf_tv_list=mean_df_pivot['Infubinol'].to_list()
inf_tv_list=[round(item, 2) for item in inf_tv_list]

# %%
#Placebo:Round the mean to two decimal point and make a list of mean of Tumor Volume 
pla_tv_list=mean_df_pivot['Placebo'].to_list()
pla_tv_list=[round(item, 2) for item in pla_tv_list]

# %%
#Preview lists
# print('Capomulin ',cap_tv_list)
# print('Ketapril  ',ket_tv_list)
# print('Infubinol ',inf_tv_list)
# print('Placebo   ',pla_tv_list)

# %% [markdown]
# Find  Standard Error of Mean (sem) of Tumor Volume(mm3) Data, Grouped by Drug and Timepoint

# %%
# Standard Error of Tumor Volume(mm3) Data, Grouped by Drug and Timepoint
sem_tv_df = pd.DataFrame(merged_df.groupby(['Drug', 'Timepoint']) ["Tumor Volume (mm3)"].sem())
#Reindexing DF
sem_tv_df=sem_tv_df.reset_index()
#preview
#sem_tv_df

# %%
# Minor Data Munging to Re-Format the Data Frames
# Preview that Reformatting worked

sem_df_pivot=sem_tv_df.pivot(index='Timepoint',columns='Drug', values='Tumor Volume (mm3)')
sem_df_pivot=sem_tv_df.pivot(index='Timepoint',columns='Drug', values='Tumor Volume (mm3)')
#preview
sem_df_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %% [markdown]
# Standard Error of Mean(sem) of Tumor Volume of four treatments (Capomulin, Infubinol, Ketapril, and Placebo).

# %%
#Capomulin :Round the Standard Error to two decimal point and make a list of SEM of Tumor Volume  
cap_sem_list=sem_df_pivot['Capomulin'].to_list()
#round the floating number to two decimal value
cap_sem_list=[round(item, 2) for item in cap_sem_list]
#cap_sem_list

# %%
#Ketapril :Round the Standard Error to two decimal point and make a list of SEM of Tumor Volume 
ket_sem_list=sem_df_pivot['Ketapril'].to_list()
#round the floating number to two decimal value
ket_sem_list=[round(item, 2) for item in ket_sem_list]
#ket_sem_list

# %%
#Infubinol:Round the Standard Error to two decimal point and make a list of SEM of Tumor Volume 
inf_sem_list=sem_df_pivot['Infubinol'].to_list()
#round the floating number to two decimal value
inf_sem_list=[round(item, 2) for item in inf_sem_list]
#inf_sem_list

# %%
#Ketapril :Round the Standard Error to two decimal point and make a list of SEM of Tumor Volume 
pla_sem_list=sem_df_pivot['Placebo'].to_list()
#round the floating number to two decimal value
pla_sem_list=[round(item, 2) for item in pla_sem_list]
#pla_sem_list

# %%
# Generate the Plot (with Error Bars)
fig, ax = plt.subplots()

#x-axis
days= np.arange(0, 50, 5)

#horzondal black line at starting tumer size for better comparing the rise in/reduction in tumor size
plt.hlines(45,0, max(days)+3, color='black')

#Plot with error bar
ax.errorbar(days,cap_tv_list,yerr=cap_sem_list, fmt="red", label="Capomulin", marker='*')

ax.errorbar(days,ket_tv_list,yerr=ket_sem_list, fmt="black", label="Ketapril", marker= '^')

ax.errorbar(days,inf_tv_list,yerr=inf_sem_list, fmt="blue",  label="Infubinol", marker ='o')

ax.errorbar(days,pla_tv_list,yerr=pla_sem_list, fmt="green",  label="Placebo", marker ='s')

#Legend location
ax.legend(loc='upper center')

#Label the axis and title
ax.set_xlabel('Time-Days')
ax.set_ylabel('Mean of Tumor Volume(mm3) with SEM')
ax.set_title('Tumor Response to Treatment')

#Set values points on the coordinate axis
tick_locations = [value for value in days]
ax.set_xticks(tick_locations, minor=False)
yvalue =np.arange(35,71,5)
yticks_location= [y1 for y1 in yvalue]
ax.set_yticks(yticks_location, minor=False)

#increase the x limit for better view
plt.xlim(0, max(days)+3)

#add grid lines
plt.grid()

#plt.tight_layout()

# Save the Figure
plt.savefig(os.path.join("Images","Tumor_response"))

#Display the graph
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## Metastatic Response to Treatment

# %% [markdown]
# Comuting the mean of Spead of Tumor

# %%
# Mean Metastatic Site Data, Grouped by Drug and Timepoint
# Convert to DataFrame
mean_meta_df = pd.DataFrame(merged_df.groupby(['Drug', 'Timepoint']) ["Metastatic Sites"].mean())

#Reindexing DF
mean_meta_df=mean_meta_df.reset_index()

# Preview DataFrame
mean_meta_df
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.160000
# 2   Capomulin         10          0.320000
# 3   Capomulin         15          0.375000
# 4   Capomulin         20          0.652174
# ..        ...        ...               ...
# 95  Zoniferol         25          1.687500
# 96  Zoniferol         30          1.933333
# 97  Zoniferol         35          2.285714
# 98  Zoniferol         40          2.785714
# 99  Zoniferol         45          3.071429
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
# Preview that Reformatting worked

mean_meta_pivot=mean_meta_df.pivot(index='Timepoint',columns='Drug', values='Metastatic Sites')

#preview
mean_meta_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %% [markdown]
# Computing the Standar Error of the mean

# %%
# Store the Standard Error associated with Metastatic Sites Grouped by Drug and Timepoint 
sem_meta_df = pd.DataFrame(merged_df.groupby(['Drug', 'Timepoint']) ["Metastatic Sites"].sem())

#Preview dataframe
sem_meta_df
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621
# ...                               ...
# Zoniferol 25                 0.236621
#           30                 0.248168
#           35                 0.285714
#           40                 0.299791
#           45                 0.286400
#
# [100 rows x 1 columns]

# %%
#Reindexing DF
sem_meta_df=sem_meta_df.reset_index()

#preview
sem_meta_df
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.074833
# 2   Capomulin         10          0.125433
# 3   Capomulin         15          0.132048
# 4   Capomulin         20          0.161621
# ..        ...        ...               ...
# 95  Zoniferol         25          0.236621
# 96  Zoniferol         30          0.248168
# 97  Zoniferol         35          0.285714
# 98  Zoniferol         40          0.299791
# 99  Zoniferol         45          0.286400
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
# Preview that Reformatting worked

sem_meta_df_pivot=sem_meta_df.pivot(index='Timepoint',columns='Drug', values='Metastatic Sites')

#preview
sem_meta_df_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %% [markdown]
# Storing the mean of each drug into a list for ploting

# %%
#Capomulin:Round the mean to two decimal point and make a list of mean of Tumor Volume 
cap_meta_list= mean_meta_pivot ['Capomulin'].to_list()
cap_meta_list=[round(item, 2) for item in cap_meta_list]
#Ketapril:Round the mean to two decimal point and make a list of mean of Tumor Volume 
ket_meta_list=mean_meta_pivot['Ketapril'].to_list()
ket_meta_list=[round(item, 2) for item in ket_meta_list]
# Infubinol :Round the mean to two decimal point and make a list of mean of Tumor Volume 
inf_meta_list=mean_meta_pivot['Infubinol'].to_list()
inf_meta_list=[round(item, 2) for item in inf_meta_list]
#Placebo:Round the mean to two decimal point and make a list of mean of Tumor Volume 
pla_meta_list=mean_meta_pivot['Placebo'].to_list()
pla_meta_list=[round(item, 2) for item in pla_meta_list]

#Preview lists
# print(cap_meta_list)
# print(ket_meta_list)
# print(inf_meta_list)
# print(pla_meta_list)

# %% [markdown]
# Mean of Standard Error

# %%
#Capomulin :Round the Standard Error to two decimal point and make a list of SEM of Tumor Volume  
cap_sem_meta_list=sem_meta_df_pivot['Capomulin'].to_list()
#round the floating number to two decimal value
cap_sem_meta_list=[round(item, 2) for item in cap_sem_meta_list]
#Ketapril :Round the Standard Error to two decimal point and make a list of SEM of Tumor Volume 
ket_sem_meta_list=sem_meta_df_pivot['Ketapril'].to_list()
#round the floating number to two decimal value
ket_sem_meta_list=[round(item, 2) for item in ket_sem_meta_list]
#Infubinol:Round the Standard Error to two decimal point and make a list of SEM of Tumor Volume 
inf_sem_meta_list=sem_meta_df_pivot['Infubinol'].to_list()
#round the floating number to two decimal value
inf_sem_meta_list=[round(item, 2) for item in inf_sem_meta_list]
#Ketapril :Round the Standard Error to two decimal point and make a list of SEM of Tumor Volume 
pla_sem_meta_list=sem_meta_df_pivot['Placebo'].to_list()
#round the floating number to two decimal value
pla_sem_meta_list=[round(item, 2) for item in pla_sem_meta_list]


#Preview lists
# print(cap_sem_meta_list)
# print(ket_sem_meta_list)
# print(inf_sem_meta_list)
# print(pla_sem_meta_list)

# %%
# Generate the Plot (with Error Bars)
fig, ay = plt.subplots()

#days= np.arange(0, 50, 5)

#Setting the axis limits
plt.xlim(0, max(days)+3)
plt.ylim(0,4)

#plotting with error bars
ay.errorbar(days,cap_meta_list,yerr=cap_sem_meta_list, fmt="red", label="Capomulin", marker='*')

ay.errorbar(days,ket_meta_list,yerr=ket_sem_meta_list, fmt="black", label="Ketapril", marker= '^')

ay.errorbar(days,inf_meta_list,yerr=inf_sem_meta_list, fmt="blue",  label="Infubinol", marker ='o')

ay.errorbar(days,pla_meta_list,yerr=pla_sem_meta_list, fmt="green",  label="Placebo", marker ='s')

#TO display the legend
ay.legend(loc='upper center')

#Labelling
ay.set_xlabel('Time-Days')
ay.set_ylabel('Mean of Metastatic Site with SEM')
ay.set_title('Metastatic Response to Treatment')

##Set values points on the coordinate 
tick_locations = [value for value in days]
ay.set_xticks(tick_locations, minor=False)

metayvalue =np.arange(0,4,0.5)
metayticks_location= [y1 for y1 in metayvalue]
ay.set_yticks(metayticks_location, minor=False)

#Add grid lines
plt.grid()

plt.tight_layout()

# Save the Figure
plt.savefig(os.path.join("Images","Metastatic_response"))

# Show the Figure
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint 
# Convert to DataFrame
mouse_count_df = pd.DataFrame(merged_df.groupby(['Drug', 'Timepoint']) ['Timepoint'].count())

#Rename column
mouse_count_df=mouse_count_df.rename(columns={'Timepoint':'Mouse Count'})

#Reindexing DF
mouse_count_df=mouse_count_df.reset_index()

#Display dataframe
mouse_count_df
# Out:
#          Drug  Timepoint  Mouse Count
# 0   Capomulin          0           25
# 1   Capomulin          5           25
# 2   Capomulin         10           25
# 3   Capomulin         15           24
# 4   Capomulin         20           23
# ..        ...        ...          ...
# 95  Zoniferol         25           16
# 96  Zoniferol         30           15
# 97  Zoniferol         35           14
# 98  Zoniferol         40           14
# 99  Zoniferol         45           14
#
# [100 rows x 3 columns]

# %% [markdown]
# SURVIVED MOUSE COUNT

# %%
# Minor Data Munging to Re-Format the Data Frames
mouse_count_pivot=mouse_count_df.pivot(index='Timepoint',columns='Drug', values='Mouse Count')

# Preview the Data Frame
mouse_count_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# ...

# %% [markdown]
# Computing the survival rate (%)

# %%
#Make a list of number of mouse survived from the above DataFrame
#For drugs Capomulin, Infubinol, Ketapril, and Placebo

#Capomulin 
cap_mouse_list= mouse_count_pivot ['Capomulin'].to_list()
#mouse survival rate with drug Capomulin
cap_survrate = [(count/cap_mouse_list[0])*100 for count in cap_mouse_list]

#Ketapril 
ket_mouse_list=mouse_count_pivot['Ketapril'].to_list()
#mouse survival rate with drug Ketapril
ket_survrate = [(count/ket_mouse_list[0])*100 for count in ket_mouse_list]

# Infubinol 
inf_mouse_list=mouse_count_pivot['Infubinol'].to_list()
#mouse survival rate with drug Infubinol
inf_survrate = [(count/inf_mouse_list[0])*100 for count in inf_mouse_list]

#Placebo 
pla_mouse_list=mouse_count_pivot['Placebo'].to_list()
#mouse survival rate with drug Placebo
pla_survrate = [(count/pla_mouse_list[0])*100 for count in pla_mouse_list]

#Display the lists
# print(cap_mouse_list)
# print(cap_survrate)
# print(ket_mouse_list)
# print(ket_survrate)
# print(inf_mouse_list)
# print(inf_survrate)
# print(pla_mouse_list)
# print(pla_survrate)

# %% [markdown]
# Plotting

# %%
fig, ax = plt.subplots()

#Days on x axis
x_axis = np.arange(0, 50, 5)

# Generate the Plot (Accounting for percentages)
ax.plot(x_axis, cap_survrate,marker='*',color='red',label="Capomulin")
ax.plot(x_axis, ket_survrate,marker='^',color='black',label="Ketapril")
ax.plot(x_axis, inf_survrate,marker='o',color='blue',label="Infubinol")
ax.plot(x_axis, pla_survrate,marker='s',color='green',label="Placebo")

#Set labels
ax.set_xlabel('Time-Days')
ax.set_ylabel('Mouse survival rate (%)')
ax.set_title('Survival during treatment')

#display legend without blocking the data
ax.legend(loc='bottom left')

#Add grid for better  analysis
ax.grid(True)

fig.tight_layout()

#Display the graph
plt.show()

# Save the Figure
plt.savefig(os.path.join("Images","Survival_rate"))
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

cap_tv_change=(round(((mean_df_pivot.iloc[9,0]-mean_df_pivot.iloc[0,0])/mean_df_pivot.iloc[0,0])*100,2))
cef_tv_change=(round(((mean_df_pivot.iloc[9,1]-mean_df_pivot.iloc[0,1])/mean_df_pivot.iloc[0,1])*100,2))
inf_tv_change=(round(((mean_df_pivot.iloc[9,2]-mean_df_pivot.iloc[0,2])/mean_df_pivot.iloc[0,2])*100,2))
ket_tv_change=(round(((mean_df_pivot.iloc[9,3]-mean_df_pivot.iloc[0,3])/mean_df_pivot.iloc[0,3])*100,2))
naf_tv_change=(round(((mean_df_pivot.iloc[9,4]-mean_df_pivot.iloc[0,4])/mean_df_pivot.iloc[0,4])*100,2))
pla_tv_change=(round(((mean_df_pivot.iloc[9,5]-mean_df_pivot.iloc[0,5])/mean_df_pivot.iloc[0,5])*100,2))
pro_tv_change=(round(((mean_df_pivot.iloc[9,6]-mean_df_pivot.iloc[0,6])/mean_df_pivot.iloc[0,6])*100,2))
ram_tv_change=(round(((mean_df_pivot.iloc[9,7]-mean_df_pivot.iloc[0,7])/mean_df_pivot.iloc[0,7])*100,2))
ste_tv_change=(round(((mean_df_pivot.iloc[9,8]-mean_df_pivot.iloc[0,8])/mean_df_pivot.iloc[0,8])*100,2))
zon_tv_change=(round(((mean_df_pivot.iloc[9,9]-mean_df_pivot.iloc[0,9])/mean_df_pivot.iloc[0,9])*100,2))

# #display results for checking
print('Capomulin',cap_tv_change)
print('Ceftamin',cef_tv_change)
print('Infubinol',inf_tv_change)
print('Ketapril',ket_tv_change)
print('Naftisol',naf_tv_change)
print('Placebo',pla_tv_change)
print('Propriva',pro_tv_change)
print('Ramicane',ram_tv_change)
print('Stelasyn',ste_tv_change)
print('Zoniferol',zon_tv_change)
# Out:
# Capomulin -19.48
# Ceftamin 42.52
# Infubinol 46.12
# Ketapril 57.03
# Naftisol 53.92
# Placebo 51.3
# Propriva 47.24
# Ramicane -22.32
# Stelasyn 52.09
# Zoniferol 46.58

# %%
# Store all Relevant drugs (Capomulin, Infubinol, Ketapril, and Placebo) Percent Changes into a Tuple
y_axis= (cap_tv_change,inf_tv_change,ket_tv_change,pla_tv_change)

x_axis = ['Capomulin', 'Infubinol', 'Ketapril', 'Placebo']

# #Display results for checking
# print(type(y_axis))
#print((y_axis))
# print(x_axis)

# %%
fig, ax = plt.subplots()

# Splice the data between passing and failing drugs
colors = []
for item in y_axis:
    if item < 0:
        colors.append('green')
    else:
        colors.append('red')

#Plot the bar graph and assign color from above list
tumor_growth_bar = ax.bar(x_axis, y_axis, color=colors, alpha=1.0, edgecolor='black', linewidth=0.7)

#Add title and axis labels
ax.set_title("Tumor Change Over 45 Day Treatment")
ax.set_ylabel("% Tumor Volume Change")
ax.set_xlabel("Drugs")

#X naming axis coordinate with drug names
xtick_locations = [value for value in x_axis]
ax.set_xticks(xtick_locations, minor=False )

#y axis coordinates values
yvalue =np.arange(-20,70,10)
yticks_location= [y2 for y2 in yvalue]
ax.set_yticks(yticks_location, minor=False)

# Tick marks 
# Set the limit of the x and y axes. lim(start, end)
plt.xlim(-1, len(x_axis))
plt.ylim(min(y_axis)-5, max(y_axis)+10)

# Plot horizontal line at y=0
plt.hlines(0, -1, len(x_axis), alpha=1.0, linewidth=0.5)

# Add gridlines
plt.grid('on', which='major', axis='y', linestyle='dotted', linewidth=0.5)

# Use functions to label the percentages of changes
def autolabel(rects, ax):
    # Get y-axis height to calculate label position from.
    (y_bottom, y_top) = ax.get_ylim()
    y_height = y_top - y_bottom

    for rect in rects:
        height = rect.get_height()

        # Fraction of axis height taken up by this rectangle
        p_height = (height / y_height)

        # To fit the label above the column
        # otherwise, put it inside the column.
        if p_height > 0.95: # arbitrary; 95% looked good to me.
            label_position = height - (y_height * 0.05)
        else:
            label_position = height + (y_height * 0.01)

        ax.text(rect.get_x() + rect.get_width()/2., label_position,
                '{}%'.format('%d' % int(height)),
                ha='center', va='bottom')

# Call functions to implement the function calls
autolabel(tumor_growth_bar,ax)

# Save the Figure
plt.savefig(os.path.join("Images","Tumor_volume_change"))

fig.tight_layout()

# Show the Figure
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
